# %%
import os
import tensorflow as tf
import keras
from keras.applications import inception_v3 as inc_net
from keras.preprocessing import image
from keras.applications.imagenet_utils import decode_predictions
from skimage.io import imread
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
model = tf.keras.models.load_model('/home/jupyter/FinalFinalModels/DenseNet/OriginalDatasetModel')

# %%
for image_path in os.listdir("/home/jupyter/large-dataset/test-data-large/Bad"):
    img = image.load_img(os.path.join("/home/jupyter/large-dataset/test-data-large/Bad", image_path), target_size=(224, 224))
    plt.imshow(img)
    img = image.img_to_array(img)/255
    prediction_scores = model.predict(np.expand_dims(img, axis=0))
    predicted_index = np.argmax(prediction_scores)
    print("Predicted label: " +str(predicted_index))
# Out:
# Predicted label: 1
# Predicted label: 1
# Predicted label: 1
# Predicted label: 1
# Predicted label: 1
# Predicted label: 1
# Predicted label: 1
# Predicted label: 0
# Predicted label: 1
# Predicted label: 0
# Predicted label: 0
# Predicted label: 1
# Predicted label: 1
# Predicted label: 0
# Predicted label: 0
# Predicted label: 1
# Predicted label: 0
# Predicted label: 0
# Predicted label: 1
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 1
# Predicted label: 1
# Predicted label: 0
# Predicted label: 1
# Predicted label: 0
# Predicted label: 1
# Predicted label: 0
# Predicted label: 0

# %%
len(os.listdir("/home/jupyter/large-dataset/test-data-large/Bad"))
# Out:
# 31

# %%
for image_path in os.listdir("/home/jupyter/large-dataset/test-data-large/Good"):
    img = image.load_img(os.path.join("/home/jupyter/large-dataset/test-data-large/Good", image_path), target_size=(224, 224))
    plt.imshow(img)
    img = image.img_to_array(img)/255
    prediction_scores = model.predict(np.expand_dims(img, axis=0))
    predicted_index = np.argmax(prediction_scores)
    print("Predicted label: " +str(predicted_index))
# Out:
# Predicted label: 0
# Predicted label: 0
# Predicted label: 1
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 1
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 1
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 1
# Predicted label: 1
# Predicted label: 0
# Predicted label: 0
# Predicted label: 1
# Predicted label: 1
# Predicted label: 1
# Predicted label: 1
# Predicted label: 0
# Predicted label: 0
# Predicted label: 1
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# Predicted label: 0
# ...
